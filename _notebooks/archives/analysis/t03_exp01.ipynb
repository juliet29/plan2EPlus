# %%
import sys
sys.path.append("/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts")

from analysis.bivariable import BiVariableAnalysis
from outputs.variables import OutputVars, PostProcessedOutputVars

from copy import copy, deepcopy

import pandas as pd

import seaborn as sns
import seaborn.objects as so

from ladybug.datacollection import HourlyContinuousCollection
from ladybug.header import Header
# Apply the default theme
sns.set_theme()

import numpy as np

# %%
bv = BiVariableAnalysis("exp01")
# bv = BiVariableAnalysis("test0")
# bv.update_qois(OutputVars.site_wind_speed, OutputVars.zone_ach)
# bv.run()

# %% [markdown]
# ## two by two

# %%
bv.update_qois(OutputVars.zone_ach, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.is_two_by_two = True
bv.run()
bv.fig
# Out:
# /Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts/outputs/sql.py:39: UserWarning: AFN Zone Ventilation Air Change Rate not in available_outputs
#   warn(f"{self.curr_output.value} not in available_outputs")
# /Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:108: UserWarning: Unable to pull data of AFN Zone Ventilation Air Change Rate for a00-base_case
#   warn(
# /Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:108: UserWarning: Unable to pull data of Zone Ventilation Net Heat Loss for a00-base_case
#   warn(

# %%
bv.update_qois(OutputVars.zone_mean_air_temp, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.is_two_by_two = True
bv.run()
bv.fig
# Out:
# /Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:108: UserWarning: Unable to pull data of Zone Ventilation Net Heat Loss for a00-base_case
#   warn(

# %%
bv.update_qois(OutputVars.zone_mean_air_temp, OutputVars.zone_ach)
bv.update_is_post_process_qoi(qoi2_bool=False)
bv.is_two_by_two = True
bv.run()
bv.fig
# Out:
# /Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts/outputs/sql.py:39: UserWarning: AFN Zone Ventilation Air Change Rate not in available_outputs
#   warn(f"{self.curr_output.value} not in available_outputs")

# %% [markdown]
# ## one by two

# %%
bv.update_qois(OutputVars.site_wind_speed, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.is_two_by_two = False
bv.is_zonal_data = True
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.run()
bv.fig
# Out:
# /Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:108: UserWarning: Unable to pull data of Zone Ventilation Net Heat Loss for a00-base_case
#   warn(

# %%
bv.sql.filtered_collection[0].header.metadata
# Out:
# {'type': 'Site Wind Speed', 'Zone': 'Environment'}

# %%
bv.update_qois(OutputVars.site_db_temp, OutputVars.zone_mean_air_temp)
bv.update_is_post_process_qoi(qoi2_bool=False)
bv.is_two_by_two = False
bv.is_zonal_data = True
bv.run()
bv.fig

# %%
bv.update_qois(OutputVars.site_db_temp, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.run()
bv.fig
# Out:
# /Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:108: UserWarning: Unable to pull data of Zone Ventilation Net Heat Loss for a00-base_case
#   warn(

# %%
bv.update_qois(OutputVars.site_diffuse_solar_rad, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.is_zonal_data = True
bv.run()
bv.fig
# Out:
# /Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:108: UserWarning: Unable to make graph of Site Diffuse Solar Radiation Rate per Area vs Zone Ventilation Net Heat Loss for a00-base_case
#   warn(

# %% [markdown]
# ## one by one

# %%
bv.update_qois(OutputVars.site_db_temp, OutputVars.site_diffuse_solar_rad)
bv.update_is_post_process_qoi(qoi2_bool=False)
bv.is_zonal_data = False
bv.run()
bv.fig
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:117, in BiVariableAnalysis.get_zone_data(self, ix)
#     116 try:
# --> 117     _, _, zone_name = zone_rename(self.var2[ix].header.metadata["System"])
#     118 except:
#
# KeyError: 'System'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 4
#       2 bv.update_is_post_process_qoi(qoi2_bool=False)
#       3 bv.is_zonal_data = False
# ----> 4 bv.run()
#       5 bv.fig
#
# File ~/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:51, in BiVariableAnalysis.run(self)
#      49     self.get_case_sqls()
#      50     self.get_case_post_processed_data()
# ---> 51 self.create_long_data()
#      52 self.make_bivariable_plot()
#
# File ~/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:77, in BiVariableAnalysis.create_long_data(self)
#      75 self.curr_case = case
#      76 if self.pull_data():
# ---> 77     self.long_data.extend(self.get_zone_data(0))
#      78     if self.is_zonal_data:
#      79         assert type(self.var2) == list
#
# File ~/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:119, in BiVariableAnalysis.get_zone_data(self, ix)
#     117     _, _, zone_name = zone_rename(self.var2[ix].header.metadata["System"])
#     118 except:
# --> 119     _, _, zone_name = zone_rename(self.var2[ix].header.metadata["Zone"])
#     122 var1_ix = ix if self.is_two_by_two else 0
#     123 return [
#     124     {
#     125         "case": self.curr_case,
#    (...)
#     131     for v1, v2 in zip(self.var1[var1_ix].values, self.var2[ix].values)
#     132 ]
#
# File ~/_UILCode/gqe-phd/geomeppy/_scripts/helpers/idf_object_rename.py:2, in zone_rename(name)
#       1 def zone_rename(name):
# ----> 2         entry_name = name.split()[1]
#       3         display_name = f"Block {entry_name}"
#       4         bunch_name = f"B_{entry_name}"
#
# IndexError: list index out of range

# %%
bv.update_qois(OutputVars.site_db_temp, OutputVars.site_wind_speed)
bv.update_is_post_process_qoi(qoi2_bool=False)
bv.is_zonal_data = False
bv.run()
bv.fig

# %%
# bv.update_qois(OutputVars.site_direct_solar_rad , OutputVars.zone_mean_air_temp)
# bv.run()

# %%
# bv.update_qois(OutputVars.site_diffuse_solar_rad , OutputVars.zone_mean_air_temp)
# bv.run()
