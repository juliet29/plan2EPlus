# %%
import sys
sys.path.append("/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts")

from outputs.sql import SQLReader
from outputs.time import TimePlot

import plotly.graph_objects as go

from outputs.output_names import OutputVariables
from outputs.site_data import SiteDataPlots

from plotly.subplots import make_subplots

# %%
sql = SiteDataPlots("test03")
sql.sqld
# Out:
# Energy SQLiteResult: cases/test03/results/eplusout.sql

# %%
sql.epcase.idf.idfobjects["SITE:LOCATION"][0].Name
# Out:
# 'DENVER_STAPLETON_CO_USA_WMO_724690'

# %%
sql.update_site_data(OutputVariables.direct_solar_rad_rate)
sql.update_site_data(OutputVariables.site_db_temp)
sql.update_site_data(OutputVariables.site_wb_temp)

# %%
sql.plot_all_site_data(1)

# %%
sql.plot_all_site_data(0)

# %%
sql.outputs
# Out:
# [<OutputVariables.direct_solar_rad_rate: 'Site Direct Solar Radiation Rate per Area'>,
#  <OutputVariables.site_db_temp: 'Site Outdoor Air Drybulb Temperature'>]

# %%
sql.plot_site_data(OutputVariables.site_db_temp, 1)

# %%
sql.plot_site_data(OutputVariables.direct_solar_rad_rate, 1)
