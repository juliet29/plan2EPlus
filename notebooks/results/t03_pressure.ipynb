# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd() / "_scripts"))

# %%
import seaborn as sns
import seaborn.objects as so
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.colors import Colormap, Normalize
from typing import Iterable
from matplotlib.cm import ScalarMappable
from sklearn.preprocessing import MinMaxScaler

from setup.data_wrangle import *
from setup.materials_setup import *
from analysis.pressure_on_network import *
from analysis.helpers import *
from analysis.plot_helpers import *
from network.network import init_multigraph


sns.set_theme()

# %%
cases = retrieve_cases()
medium_cases = [i for i in cases if "Medium" in i.case_name]
sc = medium_cases[0]

# %%
network_plots_for_many_cases(medium_cases, (12,0))

# %%
f = create_network_plot(sc, (12, 45))
