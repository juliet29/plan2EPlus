# %%
import sys
sys.path.append("/Users/julietnwagwuume-ezeoke/_UILCode/gqe-phd/geomeppy/_scripts")

from analysis.bivariable import BiVariableAnalysis
from outputs.variables import OutputVars, PostProcessedOutputVars

from copy import copy, deepcopy

import pandas as pd

import seaborn as sns
import seaborn.objects as so

from ladybug.datacollection import HourlyContinuousCollection
from ladybug.header import Header
# Apply the default theme
sns.set_theme()

import numpy as np

# %%
# bv = BiVariableAnalysis("exp01")
bv = BiVariableAnalysis("test0")
# bv.update_qois(OutputVars.site_wind_speed, OutputVars.zone_ach)
# bv.run()

# %% [markdown]
# ## two by two

# %%
type(bv.sql.filtered_collection)
# Out:
# list

# %%
bv.update_qois(OutputVars.zone_ach, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.is_two_by_two = True
bv.run()

# %%
bv.update_qois(OutputVars.zone_mean_air_temp, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.is_two_by_two = True
bv.run()

# %%
bv.update_qois(OutputVars.zone_mean_air_temp, OutputVars.zone_ach)
bv.update_is_post_process_qoi(qoi2_bool=False)
bv.is_two_by_two = True
bv.run()

# %% [markdown]
# ## one by two

# %%
bv.update_qois(OutputVars.site_wind_speed, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.run()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 bv.update_qois(OutputVars.site_wind_speed, PostProcessedOutputVars.zone_vent_net_heat_loss)
#       2 bv.update_is_post_process_qoi(qoi2_bool=True)
# ----> 3 bv.run()
#
# File ~/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:48, in BiVariableAnalysis.run(self)
#      46     self.get_case_sqls()
#      47     self.get_case_post_processed_data()
# ---> 48 self.create_long_data()
#      49 self.make_bivariable_plot()
#      50 self.fig.show()
#
# File ~/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:80, in BiVariableAnalysis.create_long_data(self)
#      78             for zone_ix, _ in enumerate(self.var2):
#      79                 if ix==0:
# ---> 80                     pass
#      81                 self.long_data.extend(self.get_zone_data(zone_ix))
#      82 self.df = pd.DataFrame(self.long_data)
#
# File ~/_UILCode/gqe-phd/geomeppy/_scripts/analysis/bivariable.py:123, in get_zone_data(self, ix)
#     113 var1_ix = ix if self.is_two_by_two else 0
#     114 assert type(self.var1)== list and type(self.var2)== list
#     115 return [
#     116     {
#     117         "case": self.curr_case,
#     118         "zone": v2.header.metadata["System"],
#     119         self.qoi1.name: v1,
#     120         self.qoi2.name: v2,
#     121     }
#     122
# --> 123     for v1, v2 in zip(self.var1[var1_ix].values, self.var2[ix].values)
#     124 ]
#
# IndexError: list index out of range

# %%
bv.update_qois(OutputVars.site_db_temp, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.run()

# %%
bv.update_qois(OutputVars.site_diffuse_solar_rad, PostProcessedOutputVars.zone_vent_net_heat_loss)
bv.update_is_post_process_qoi(qoi2_bool=True)
bv.is_zonal_data = True
bv.run()

# %% [markdown]
# ## one by one

# %%
bv.update_qois(OutputVars.site_db_temp, OutputVars.site_diffuse_solar_rad)
bv.update_is_post_process_qoi(qoi2_bool=False)
bv.is_zonal_data = False
bv.run()

# %%
bv.update_qois(OutputVars.site_db_temp, OutputVars.site_wind_speed)
bv.update_is_post_process_qoi(qoi2_bool=False)
bv.is_zonal_data = False
bv.run()

# %%
# bv.update_qois(OutputVars.site_direct_solar_rad , OutputVars.zone_mean_air_temp)
# bv.run()

# %%
# bv.update_qois(OutputVars.site_diffuse_solar_rad , OutputVars.zone_mean_air_temp)
# bv.run()
